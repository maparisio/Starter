# %% [markdown]
# # Geoapify Drills
#
# Create code to answer each of the following questions.
#
# > **Hint:** You will need multiple target URLs and multiple API requests.

# %%
# Dependencies
import requests
import json

# Import the API key
from config import geoapify_key
geoapify_key
# Out:
# 'eaacf2d1dabe437fa746b3c4b9007909'

# %% [markdown]
# ## 1. What are the geocoordinates (latitude and longitude) of Brisbane, Australia?

# %%
# Set the search parameters
target_city = "Brisbane, Australia"

params = {
    "text": target_city,
    "apiKey": geoapify_key
}

# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "bbox": [
#                 152.679693,
#                 -27.660219,
#                 153.468275,
#                 -27.022014
#             ],
#             "geometry": {
#                 "coordinates": [
#                     153.0234991,
#                     -27.4689682
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Brisbane City",
#                 "address_line2": "QLD, Australia",
#                 "category": "administrative",
#                 "city": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Brisbane City, QLD, Australia",
#                 "lat": -27.4689682,
#                 "lon": 153.0234991,
#                 "place_id": "51893f2f81c0206340592eddc94c0e783bc0f00101f9016030b20000000000c00208",
#                 "plus_code": "5R4MG2JF+C9",
#                 "rank": {
#                     "confidence": 0.9,
#                     "confidence_city_level": 0.9,
#                     "importance": 0.8694082277592821,
#                     "match_type": "full_match",
#                     "popularity": 6.876406158741578
#                 },
#                 "result_type": "city",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "timezone": {
#                     "abbreviation_DST": "AEST",
#                     "abbreviation_STD": "AEST",
#                     "name": "Australia/Brisbane",
#                     "offset_DST": "+10:00",
#                     "offset_DST_seconds": 36000,
#                     "offset_STD": "+10:00",
#                     "offset_STD_seconds": 36000
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "brisbane",
#             "country": "australia",
#             "expected_type": "city"
#         },
#         "text": "Brisbane, Australia"
#     },
#     "type": "FeatureCollection"
# }

# %%
# Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]

# Print results
print(f"{target_city}: {lat}, {lon}")
lat = response["features"]
# Out:
# Brisbane, Australia: -27.4689682, 153.0234991

# %% [markdown]
# ## 2. What are the geocoordinates (latitude and longitude) of The Sydney Opera House?

# %%
# update params dict
target_city = "Sydney Opera House"
params = {
    "text" : target_city,
    "apiKey": geoapify_key
}

# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "bbox": [
#                 151.214428,
#                 -33.8579291,
#                 151.2158894,
#                 -33.856305
#             ],
#             "geometry": {
#                 "coordinates": [
#                     151.21512338473752,
#                     -33.85719805
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sydney Opera House",
#                 "address_line2": "2 Macquarie Street, Sydney NSW 2000, Australia",
#                 "category": "entertainment.culture.arts_centre",
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "district": "Quay Quarter",
#                 "formatted": "Sydney Opera House, 2 Macquarie Street, Sydney NSW 2000, Australia",
#                 "housenumber": "2",
#                 "lat": -33.85719805,
#                 "lon": 151.21512338473752,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Sydney Opera House",
#                 "place_id": "51aec16f4ae2e6624059f5786baab8ed40c0f00101f901c86f920000000000c002019203125379646e6579204f7065726120486f757365",
#                 "plus_code": "4RRH46V8+42",
#                 "plus_code_short": "V8+42 Sydney, New South Wales, Australia",
#                 "postcode": "2000",
#                 "rank": {
#                     "confidence": 1,
#                     "importance": 0.8439868225769328,
#                     "match_type": "full_match",
#                     "popularity": 6.979585085597298
#                 },
#                 "result_type": "amenity",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Macquarie Street",
#                 "suburb": "Sydney",
#                 "timezone": {
#                     "abbreviation_DST": "AEDT",
#                     "abbreviation_STD": "AEST",
#                     "name": "Australia/Sydney",
#                     "offset_DST": "+11:00",
#                     "offset_DST_seconds": 39600,
#                     "offset_STD": "+10:00",
#                     "offset_STD_seconds": 36000
#                 }
#             },
#             "type": "Feature"
#         },
#         {
#             "bbox": [
#                 -105.0905037,
#                 39.263046,
#                 -105.0899454,
#                 39.2632642
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -105.09021131983177,
#                     39.2631531
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sydney Opera House",
#                 "address_line2": "Douglas County, CO, United States of America",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Douglas County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Sydney Opera House, Douglas County, CO, United States of America",
#                 "lat": 39.2631531,
#                 "lon": -105.09021131983177,
#                 "name": "Sydney Opera House",
#                 "place_id": "51031ab305c6455ac059a62b3300afa14340f00102f901a9d8214700000000c002019203125379646e6579204f7065726120486f757365",
#                 "plus_code": "85FP7W75+7W",
#                 "rank": {
#                     "confidence": 1,
#                     "importance": 0.50001,
#                     "match_type": "full_match",
#                     "popularity": 1.8358464436716186
#                 },
#                 "result_type": "amenity",
#                 "state": "Colorado",
#                 "state_code": "CO",
#                 "timezone": {
#                     "abbreviation_DST": "MDT",
#                     "abbreviation_STD": "MST",
#                     "name": "America/Denver",
#                     "offset_DST": "-06:00",
#                     "offset_DST_seconds": -21600,
#                     "offset_STD": "-07:00",
#                     "offset_STD_seconds": -25200
#                 }
#             },
#             "type": "Feature"
#         },
#         {
#             "bbox": [
#                 116.2844042,
#                 39.8077821,
#                 116.2845042,
#                 39.8078821
#             ],
#             "geometry": {
#                 "coordinates": [
#                     116.2844542,
#                     39.8078321
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sydney Opera House",
#                 "address_line2": "\u8446\u53f0\u8def, Hua\u2018xiang, 100070 Beijing, China",
#                 "category": "tourism.attraction",
#                 "city": "Fengtai District",
#                 "country": "China",
#                 "country_code": "cn",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Sydney Opera House, \u8446\u53f0\u8def, Hua\u2018xiang, 100070 Beijing, China",
#                 "lat": 39.8078321,
#                 "lon": 116.2844542,
#                 "name": "Sydney Opera House",
#                 "place_id": "516e8d637f34125d40595a14d10a67e74340f00103f9015173cdbd00000000c002019203125379646e6579204f7065726120486f757365",
#                 "plus_code": "8PFRR75M+4Q",
#                 "postcode": "100070",
#                 "rank": {
#                     "confidence": 1,
#                     "importance": 0.30001,
#                     "match_type": "full_match",
#                     "popularity": 2.6769029610356663
#                 },
#                 "result_type": "amenity",
#                 "state": "Beijing",
#                 "street": "\u8446\u53f0\u8def",
#                 "suburb": "Hua\u2018xiang",
#                 "timezone": {
#                     "abbreviation_DST": "CST",
#                     "abbreviation_STD": "CST",
#                     "name": "Asia/Shanghai",
#                     "offset_DST": "+08:00",
#                     "offset_DST_seconds": 28800,
#                     "offset_STD": "+08:00",
#                     "offset_STD_seconds": 28800
#                 },
#                 "village": "\u90ed\u516c\u5e84\u6751"
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "text": "Sydney Opera House"
#     },
#     "type": "FeatureCollection"
# }

# %%
# Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]

# Print results
print(f"{target_city}: {lat}, {lon}")
# Out:
# Sydney Opera House: -27.4689682, 153.0234991

# %% [markdown]
# ## 3. Find the name and address of a pharmacy in Brisbane, Australia.
#
# > **Hint:** Review <https://apidocs.geoapify.com/docs/places/#categories>.

# %%
# Set the geographical coordinates for Brisbane, Australia
latitude = -27.4705
longitude = 153.0260

# Set the parameters for the type of place
categories = "healthcare.pharmacy"

# Set the parameters for the type of search
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "limit":limit,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.02486289999996,
#                     -27.469754799462155
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Priceline Pharmacy",
#                 "address_line2": "120 Queen Street, Brisbane City QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "brand": "Priceline Pharmacy",
#                         "brand:wikidata": "Q7242652",
#                         "brand:wikipedia": "en:Priceline (Australia)",
#                         "healthcare": "pharmacy",
#                         "name": "Priceline Pharmacy",
#                         "osm_id": 1546536181,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 139,
#                 "district": "Greater Brisbane",
#                 "formatted": "Priceline Pharmacy, 120 Queen Street, Brisbane City QLD 4000, Australia",
#                 "housenumber": "120",
#                 "lat": -27.4697548,
#                 "lon": 153.0248629,
#                 "name": "Priceline Pharmacy",
#                 "neighbourhood": "Golden Triangle",
#                 "place_id": "5146cc47adcb2063405939d4bcd941783bc0f00103f901f5442e5c0000000092031250726963656c696e6520506861726d616379",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Queen Street",
#                 "suburb": "Brisbane City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.0268978,
#                     -27.47154169946197
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Priceline Pharmacy",
#                 "address_line2": "108 Albert Street, Brisbane City QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "brand": "Priceline Pharmacy",
#                         "brand:wikidata": "Q7242652",
#                         "brand:wikipedia": "en:Priceline (Australia)",
#                         "healthcare": "pharmacy",
#                         "name": "Priceline Pharmacy",
#                         "osm_id": 1541754211,
#                         "osm_type": "n",
#                         "toilets:wheelchair": "no",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "distance": 146,
#                 "district": "Brisbane City",
#                 "formatted": "Priceline Pharmacy, 108 Albert Street, Brisbane City QLD 4000, Australia",
#                 "housenumber": "108",
#                 "lat": -27.4715417,
#                 "lon": 153.0268978,
#                 "name": "Priceline Pharmacy",
#                 "neighbourhood": "Golden Triangle",
#                 "place_id": "51b36ac658dc20634059b1e3f1f4b6783bc0f00103f901634de55b0000000092031250726963656c696e6520506861726d616379",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Albert Street",
#                 "suburb": "Brisbane City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.024774,
#                     -27.46900499946224
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Wizard Pharmacy",
#                 "address_line2": "Queen Street Mall, Brisbane City QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "healthcare": "pharmacy",
#                         "name": "Wizard Pharmacy",
#                         "osm_id": 6320207377,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 205,
#                 "district": "Greater Brisbane",
#                 "formatted": "Wizard Pharmacy, Queen Street Mall, Brisbane City QLD 4000, Australia",
#                 "lat": -27.469005,
#                 "lon": 153.024774,
#                 "name": "Wizard Pharmacy",
#                 "neighbourhood": "Golden Triangle",
#                 "place_id": "5151f9d7f2ca20634059cf592eb610783bc0f00103f90111b6b6780100000092030f57697a61726420506861726d616379",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Queen Street Mall",
#                 "suburb": "Brisbane City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.0238264,
#                     -27.47057739946206
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Chemist Warehouse",
#                 "address_line2": "60 Queen Street, Brisbane City QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "brand": "Chemist Warehouse",
#                         "brand:wikidata": "Q48782120",
#                         "brand:wikipedia": "en:Chemist Warehouse",
#                         "healthcare": "pharmacy",
#                         "name": "Chemist Warehouse",
#                         "osm_id": 5151109719,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 215,
#                 "district": "Greater Brisbane",
#                 "formatted": "Chemist Warehouse, 60 Queen Street, Brisbane City QLD 4000, Australia",
#                 "housenumber": "60",
#                 "lat": -27.4705774,
#                 "lon": 153.0238264,
#                 "name": "Chemist Warehouse",
#                 "neighbourhood": "Golden Triangle",
#                 "place_id": "510119952fc32063405920edacc277783bc0f00103f90157b20733010000009203114368656d6973742057617265686f757365",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Queen Street",
#                 "suburb": "Brisbane City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.027627,
#                     -27.468605199462253
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Priceline Pharmacy",
#                 "address_line2": "Edward Street, Brisbane City QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "brand": "Priceline Pharmacy",
#                         "brand:wikidata": "Q7242652",
#                         "brand:wikipedia": "en:Priceline (Australia)",
#                         "dispensing": "yes",
#                         "healthcare": "pharmacy",
#                         "name": "Priceline Pharmacy",
#                         "osm_id": 8140167944,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 264,
#                 "district": "Greater Brisbane",
#                 "formatted": "Priceline Pharmacy, Edward Street, Brisbane City QLD 4000, Australia",
#                 "lat": -27.4686052,
#                 "lon": 153.027627,
#                 "name": "Priceline Pharmacy",
#                 "neighbourhood": "Golden Triangle",
#                 "place_id": "5192af0452e2206340590a6da682f6773bc0f00103f901081b31e50100000092031250726963656c696e6520506861726d616379",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Edward Street",
#                 "suburb": "Brisbane City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.02900749999998,
#                     -27.47025849946209
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Chemist Warehouse",
#                 "address_line2": "Edward Street, Brisbane City QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:state": "QLD",
#                         "addr:suburb": "Brisbane",
#                         "amenity": "pharmacy",
#                         "brand": "Chemist Warehouse",
#                         "brand:wikidata": "Q48782120",
#                         "brand:wikipedia": "en:Chemist Warehouse",
#                         "dispensing": "yes",
#                         "healthcare": "pharmacy",
#                         "name": "Chemist Warehouse",
#                         "osm_id": 8140167945,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 298,
#                 "district": "Brisbane City",
#                 "formatted": "Chemist Warehouse, Edward Street, Brisbane City QLD 4000, Australia",
#                 "lat": -27.4702585,
#                 "lon": 153.0290075,
#                 "name": "Chemist Warehouse",
#                 "neighbourhood": "Golden Triangle",
#                 "place_id": "51d6fa22a1ed2063405910db6bdc62783bc0f00103f901091b31e5010000009203114368656d6973742057617265686f757365",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Edward Street",
#                 "suburb": "Brisbane City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.02753079999997,
#                     -27.46753149946238
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Post Office Square Pharmacy",
#                 "address_line2": "Queen Street, Brisbane City QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city_district": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "healthcare": "pharmacy",
#                         "layer": -1,
#                         "name": "Post Office Square Pharmacy",
#                         "osm_id": 1546982742,
#                         "osm_type": "n",
#                         "toilets:wheelchair": "no",
#                         "wheelchair": "yes",
#                         "wheelchair:description": "Accessible via Adelaide Street entrance"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "distance": 362,
#                 "district": "Greater Brisbane",
#                 "formatted": "Post Office Square Pharmacy, Queen Street, Brisbane City QLD 4000, Australia",
#                 "lat": -27.4675315,
#                 "lon": 153.0275308,
#                 "name": "Post Office Square Pharmacy",
#                 "neighbourhood": "Golden Triangle",
#                 "place_id": "513eb44588e1206340596f0af424b0773bc0f00103f9015615355c0000000092031b506f7374204f66666963652053717561726520506861726d616379",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Queen Street",
#                 "suburb": "Brisbane City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.0217986,
#                     -27.469351399462198
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Wizard Pharmacy",
#                 "address_line2": "336 George Street, Brisbane City QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "healthcare": "pharmacy",
#                         "name": "Wizard Pharmacy",
#                         "osm_id": 1546700978,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 434,
#                 "district": "Greater Brisbane",
#                 "formatted": "Wizard Pharmacy, 336 George Street, Brisbane City QLD 4000, Australia",
#                 "housenumber": "336",
#                 "lat": -27.4693514,
#                 "lon": 153.0217986,
#                 "name": "Wizard Pharmacy",
#                 "place_id": "512843fa92b220634059a005cf6927783bc0f00103f901b2c8305c0000000092030f57697a61726420506861726d616379",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "George Street",
#                 "suburb": "Brisbane City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.02940839999997,
#                     -27.477978099461303
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Priceline Pharmacy",
#                 "address_line2": "2 George Street, Brisbane City QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "brand": "Priceline Pharmacy",
#                         "brand:wikidata": "Q7242652",
#                         "healthcare": "pharmacy",
#                         "name": "Priceline Pharmacy",
#                         "osm_id": 11182950824,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 895,
#                 "district": "Brisbane City",
#                 "formatted": "Priceline Pharmacy, 2 George Street, Brisbane City QLD 4000, Australia",
#                 "housenumber": "2",
#                 "lat": -27.4779781,
#                 "lon": 153.0294084,
#                 "name": "Priceline Pharmacy",
#                 "neighbourhood": "Golden Triangle",
#                 "place_id": "514887e2e9f020634059fa63d1c55c7a3bc0f00103f901a8498e9a0200000092031250726963656c696e6520506861726d616379",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "George Street",
#                 "suburb": "Brisbane City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.03050839999997,
#                     -27.46199189946293
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Priceline Pharmacy",
#                 "address_line2": "365 Turbot Street, Spring Hill QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "Spring Hill",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "brand": "Priceline Pharmacy",
#                         "brand:wikidata": "Q7242652",
#                         "brand:wikipedia": "en:Priceline (Australia)",
#                         "healthcare": "pharmacy",
#                         "name": "Priceline Pharmacy",
#                         "name:en": "Priceline Pharmacy",
#                         "opening_hours": "Mo-Fr 08:00-19:00; Sa 09:00-17:00; Su 10:00-16:00",
#                         "osm_id": 4797796121,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 1043,
#                 "district": "Greater Brisbane",
#                 "formatted": "Priceline Pharmacy, 365 Turbot Street, Spring Hill QLD 4000, Australia",
#                 "housenumber": "365",
#                 "lat": -27.4619919,
#                 "lon": 153.0305084,
#                 "name": "Priceline Pharmacy",
#                 "place_id": "511a88c0ecf920634059d035e31945763bc0f00103f901198ff81d0100000092031250726963656c696e6520506861726d616379",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Turbot Street",
#                 "suburb": "Spring Hill"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.02356549999996,
#                     -27.482002499460897
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "TerryWhite Chemmart",
#                 "address_line2": "Grey Street, South Brisbane QLD 4101, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "South Brisbane",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "brand": "TerryWhite Chemmart",
#                         "brand:wikidata": "Q24089773",
#                         "brand:wikipedia": "en:Terry White Chemmart",
#                         "dispensing": "yes",
#                         "healthcare": "pharmacy",
#                         "name": "TerryWhite Chemmart",
#                         "osm_id": 8685936422,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 1297,
#                 "district": "Greater Brisbane",
#                 "formatted": "TerryWhite Chemmart, Grey Street, South Brisbane QLD 4101, Australia",
#                 "lat": -27.4820025,
#                 "lon": 153.0235655,
#                 "name": "TerryWhite Chemmart",
#                 "neighbourhood": "South Bank",
#                 "place_id": "510a7a6f0cc1206340595ac60b84647b3bc0f00103f90126dfb8050200000092031354657272795768697465204368656d6d617274",
#                 "postcode": "4101",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Grey Street",
#                 "suburb": "South Brisbane"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.0139689,
#                     -27.46541889946259
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Barracks Pharmacy",
#                 "address_line2": "61 Petrie Terrace, Petrie Terrace QLD 4000, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Brisbane City",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "healthcare": "pharmacy",
#                         "name": "Barracks Pharmacy",
#                         "opening_hours": "Mo-We,Fr 08:00-17:00, Th 08:00-19:30, Sa 08:00-14:00, Su 09:00-13:00",
#                         "osm_id": 5045884261,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "distance": 1316,
#                 "district": "Petrie Terrace",
#                 "formatted": "Barracks Pharmacy, 61 Petrie Terrace, Petrie Terrace QLD 4000, Australia",
#                 "housenumber": "61",
#                 "lat": -27.4654189,
#                 "lon": 153.0139689,
#                 "name": "Barracks Pharmacy",
#                 "place_id": "512815e86e7220634059d42168b125773bc0f00103f9016515c22c010000009203114261727261636b7320506861726d616379",
#                 "postcode": "4000",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Petrie Terrace",
#                 "suburb": "Petrie Terrace"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.03557819999997,
#                     -27.48085839946103
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Coffey",
#                 "address_line2": "Main Street, Kangaroo Point QLD 4169, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city_district": "Kangaroo Point",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "healthcare": "pharmacy",
#                         "name": "Coffey",
#                         "osm_id": 6052259527,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "distance": 1488,
#                 "district": "Greater Brisbane",
#                 "formatted": "Coffey, Main Street, Kangaroo Point QLD 4169, Australia",
#                 "lat": -27.4808584,
#                 "lon": 153.0355782,
#                 "name": "Coffey",
#                 "place_id": "516aaee474232163405929b13b89197b3bc0f00103f901c726be6801000000920306436f66666579",
#                 "postcode": "4169",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Main Street",
#                 "suburb": "Kangaroo Point"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.01198620000002,
#                     -27.476914599461413
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "West End Discount Drug Stores",
#                 "address_line2": "Mollison Street, West End QLD 4101, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "South Brisbane",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:postcode": 4101,
#                         "amenity": "pharmacy",
#                         "name": "West End Discount Drug Stores",
#                         "opening_hours": "Mo-Fr 08:00-20:00; Sa 08:00-17:00; Su 09:00-18:00",
#                         "osm_id": 506174931,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 1557,
#                 "district": "Greater Brisbane",
#                 "formatted": "West End Discount Drug Stores, Mollison Street, West End QLD 4101, Australia",
#                 "lat": -27.4769146,
#                 "lon": 153.0119862,
#                 "name": "West End Discount Drug Stores",
#                 "place_id": "511c20e2306220634059f5ab3f13177a3bc0f00103f901d39d2b1e0000000092031d5765737420456e6420446973636f756e7420447275672053746f726573",
#                 "postcode": "4101",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Mollison Street",
#                 "suburb": "West End"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.0277626,
#                     -27.4849501994606
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Mater Pharmacy",
#                 "address_line2": "Raymond Terrace, South Brisbane QLD 4101, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "South Brisbane",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "dispensing": "yes",
#                         "drive_through": "no",
#                         "healthcare": "pharmacy",
#                         "name": "Mater Pharmacy",
#                         "opening_hours": "Mo-Fr 08:00-18:00",
#                         "osm_id": 6649314305,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 1611,
#                 "district": "Greater Brisbane",
#                 "formatted": "Mater Pharmacy, Raymond Terrace, South Brisbane QLD 4101, Australia",
#                 "lat": -27.4849502,
#                 "lon": 153.0277626,
#                 "name": "Mater Pharmacy",
#                 "place_id": "51a961646ee32063405938df3eb2257c3bc0f00103f901017c548c0100000092030e4d6174657220506861726d616379",
#                 "postcode": "4101",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Raymond Terrace",
#                 "suburb": "South Brisbane"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.0115955,
#                     -27.477398299461374
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "TerryWhite Chemmart",
#                 "address_line2": "97 Boundary Street, West End QLD 4101, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "West End",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "brand": "TerryWhite Chemmart",
#                         "brand:wikidata": "Q24089773",
#                         "brand:wikipedia": "en:Terry White Chemmart",
#                         "healthcare": "pharmacy",
#                         "name": "TerryWhite Chemmart",
#                         "osm_id": 8924429400,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 1616,
#                 "district": "Greater Brisbane",
#                 "formatted": "TerryWhite Chemmart, 97 Boundary Street, West End QLD 4101, Australia",
#                 "housenumber": "97",
#                 "lat": -27.4773983,
#                 "lon": 153.0115955,
#                 "name": "TerryWhite Chemmart",
#                 "neighbourhood": "Hill End",
#                 "place_id": "51fca886fd5e20634059455a63c6367a3bc0f00103f90158fcef130200000092031354657272795768697465204368656d6d617274",
#                 "postcode": "4101",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Boundary Street",
#                 "suburb": "West End"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.0198823,
#                     -27.484505299460643
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Gladstone Road Pharmacy",
#                 "address_line2": "30-34 Gladstone Road, Highgate Hill QLD 4101, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "Highgate Hill",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "name": "Gladstone Road Pharmacy",
#                         "osm_id": 506174928,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 1666,
#                 "district": "Greater Brisbane",
#                 "formatted": "Gladstone Road Pharmacy, 30-34 Gladstone Road, Highgate Hill QLD 4101, Australia",
#                 "housenumber": "30-34",
#                 "lat": -27.4845053,
#                 "lon": 153.0198823,
#                 "name": "Gladstone Road Pharmacy",
#                 "place_id": "519e8834e0a22063405912ec0f8a087c3bc0f00103f901d09d2b1e00000000920317476c616473746f6e6520526f616420506861726d616379",
#                 "postcode": "4101",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Gladstone Road",
#                 "suburb": "Highgate Hill"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.01221809999998,
#                     -27.480878899461022
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "TerryWhite Chemmart",
#                 "address_line2": "154 Boundary Street, West End QLD 4101, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city_district": "West End",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "pharmacy",
#                         "brand": "TerryWhite Chemmart",
#                         "brand:wikidata": "Q24089773",
#                         "brand:wikipedia": "en:Terry White Chemmart",
#                         "healthcare": "pharmacy",
#                         "name": "TerryWhite Chemmart",
#                         "opening_hours": "Mo-Sa 08:00-19:00; Su 08:00-16:00",
#                         "osm_id": 2798568500,
#                         "osm_type": "n",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "distance": 1783,
#                 "district": "Greater Brisbane",
#                 "formatted": "TerryWhite Chemmart, 154 Boundary Street, West End QLD 4101, Australia",
#                 "housenumber": "154",
#                 "lat": -27.4808789,
#                 "lon": 153.0122181,
#                 "name": "TerryWhite Chemmart",
#                 "neighbourhood": "Hill End",
#                 "place_id": "516a7d3617642063405985852ae11a7b3bc0f00103f90134c4cea60000000092031354657272795768697465204368656d6d617274",
#                 "postcode": "4101",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Boundary Street",
#                 "suburb": "West End"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.0120306,
#                     -27.480687799461034
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Andrew Thanos Pharmacy",
#                 "address_line2": "197A Boundary Street, West End QLD 4101, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city_district": "West End",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "197A",
#                         "addr:street": "Boundary Street",
#                         "amenity": "pharmacy",
#                         "dispensing": "yes",
#                         "drive_through": "no",
#                         "healthcare": "pharmacy",
#                         "name": "Andrew Thanos Pharmacy",
#                         "osm_id": 5960364324,
#                         "osm_type": "n",
#                         "phone": "+61738443086",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "distance": 1783,
#                 "district": "Greater Brisbane",
#                 "formatted": "Andrew Thanos Pharmacy, 197A Boundary Street, West End QLD 4101, Australia",
#                 "housenumber": "197A",
#                 "lat": -27.4806878,
#                 "lon": 153.0120306,
#                 "name": "Andrew Thanos Pharmacy",
#                 "neighbourhood": "Hill End",
#                 "place_id": "51a431ff8d622063405977450a5b0e7b3bc0f00103f90124f1436301000000920316416e64726577205468616e6f7320506861726d616379",
#                 "postcode": "4101",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Boundary Street",
#                 "suburb": "West End"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     153.0288273,
#                     -27.4879561994603
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Taylor Medical Centre",
#                 "address_line2": "Catherine Street, Woolloongabba QLD 4102, Australia",
#                 "categories": [
#                     "commercial.health_and_beauty",
#                     "commercial.health_and_beauty.pharmacy",
#                     "healthcare",
#                     "healthcare.pharmacy"
#                 ],
#                 "city_district": "Woolloongabba",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:postcode": 4102,
#                         "amenity": "pharmacy",
#                         "healthcare": "pharmacy",
#                         "name": "Taylor Medical Centre",
#                         "osm_id": 431441647,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 1954,
#                 "district": "Greater Brisbane",
#                 "formatted": "Taylor Medical Centre, Catherine Street, Woolloongabba QLD 4102, Australia",
#                 "lat": -27.4879562,
#                 "lon": 153.0288273,
#                 "name": "Taylor Medical Centre",
#                 "neighbourhood": "Gabba Hill",
#                 "place_id": "516cd73a27ec20634059fc8f8eb2ea7c3bc0f00103f901ef46b719000000009203155461796c6f72204d65646963616c2043656e747265",
#                 "postcode": "4102",
#                 "state": "Queensland",
#                 "state_code": "QLD",
#                 "street": "Catherine Street",
#                 "suburb": "Woolloongabba"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
# Print the results
print(response["features"][0]["properties"]["name"])
print(response["features"][0]["properties"]["address_line2"])
# Out:
# Priceline Pharmacy
# 120 Queen Street, Brisbane City QLD 4000, Australia

# %% [markdown]
# ## 4. Find a pet shop within a 5km radius from the Sydney Opera House.

# %%
# Set the geographical coordinates for the Sydney Opera House
latitude = -33.85729805
longitude = 151.21512338473752

# Set the parameters for the type of place
categories = "commercial.pet"
radius = 5000

# Set the parameters for the type of search
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "limit":limit,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.22785899999997,
#                     -33.87202299966735
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Pets Point",
#                 "address_line2": "Elizabeth Bay Road, Elizabeth Bay NSW 2011, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:unit": "Shop 4",
#                         "name": "Pets Point",
#                         "osm_id": 10580904979,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 2014,
#                 "formatted": "Pets Point, Elizabeth Bay Road, Elizabeth Bay NSW 2011, Australia",
#                 "lat": -33.872023,
#                 "lon": 151.227859,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Pets Point",
#                 "place_id": "512c23f59e4ae76240592e771c739eef40c0f00103f90113ccab760200000092030a5065747320506f696e74",
#                 "postcode": "2011",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Elizabeth Bay Road",
#                 "suburb": "Elizabeth Bay"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2098816,
#                     -33.88421939966951
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Petbarn",
#                 "address_line2": "Foveaux Street, Surry Hills NSW 2010, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "name": "Petbarn",
#                         "osm_id": 10948424184,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 3025,
#                 "district": "Strawberry Hills",
#                 "formatted": "Petbarn, Foveaux Street, Surry Hills NSW 2010, Australia",
#                 "lat": -33.8842194,
#                 "lon": 151.2098816,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Petbarn",
#                 "place_id": "5107019e59b7e6624059df08ee192ef140c0f00103f901f8b1938c020000009203075065746261726e",
#                 "postcode": "2010",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Foveaux Street",
#                 "suburb": "Surry Hills"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.24449289999998,
#                     -33.87744329966832
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Petbarn",
#                 "address_line2": "New South Head Road, Double Bay NSW 2028, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Woollahra Municipal Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "check_date": "2023-08-18",
#                         "name": "Petbarn",
#                         "osm_id": 4925657661,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 3518,
#                 "district": "Eastern Suburbs",
#                 "formatted": "Petbarn, New South Head Road, Double Bay NSW 2028, Australia",
#                 "lat": -33.8774433,
#                 "lon": 151.2444929,
#                 "name": "Petbarn",
#                 "place_id": "515533c6e2d2e7624059bb15e20f50f040c0f00103f9013d929725010000009203075065746261726e",
#                 "postcode": "2028",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "New South Head Road",
#                 "suburb": "Double Bay"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.200736,
#                     -33.82283299965868
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Petbarn",
#                 "address_line2": "160 Willoughby Road, Crows Nest NSW 2065, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "North Sydney Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:country": "AU",
#                         "addr:housenumber": 160,
#                         "addr:postcode": 2065,
#                         "addr:state": "NSW",
#                         "addr:street": "Willoughby Road",
#                         "addr:suburb": "Crows Nest",
#                         "brand": "Petbarn",
#                         "brand:wikidata": "Q104746468",
#                         "name": "Petbarn",
#                         "operator": "Petbarn",
#                         "osm_id": 2625901404,
#                         "osm_type": "n",
#                         "shop": "pet",
#                         "website": "https://www.petbarn.com.au/store-finder/crows-nest"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 4048,
#                 "district": "Lower North Shore",
#                 "formatted": "Petbarn, 160 Willoughby Road, Crows Nest NSW 2065, Australia",
#                 "housenumber": "160",
#                 "lat": -33.822833,
#                 "lon": 151.200736,
#                 "name": "Petbarn",
#                 "neighbourhood": "Crows Nest Junction",
#                 "place_id": "512864e76d6ce662405943cd7b9752e940c0f00103f9015c13849c000000009203075065746261726e",
#                 "postcode": "2065",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Willoughby Road",
#                 "suburb": "Crows Nest"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.1758722,
#                     -33.87607649966807
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Pet O",
#                 "address_line2": "1A The Crescent, Annandale NSW 2038, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": "1A",
#                         "addr:street": "The Crescent",
#                         "name": "Pet O",
#                         "osm_id": 7726482861,
#                         "osm_type": "n",
#                         "shop": "pet",
#                         "website": "https://peto.com.au/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 4187,
#                 "district": "Inner West",
#                 "formatted": "Pet O, 1A The Crescent, Annandale NSW 2038, Australia",
#                 "housenumber": "1A",
#                 "lat": -33.8760765,
#                 "lon": 151.1758722,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Pet O",
#                 "place_id": "51d168bcbea0e56240592c6f554623f040c0f00103f901adc588cc01000000920305506574204f",
#                 "postcode": "2038",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "The Crescent",
#                 "suburb": "Annandale"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2436647,
#                     -33.890569499670654
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Dogue",
#                 "address_line2": "Oxford Street, Bondi Junction NSW 2022, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Waverley Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "name": "Dogue",
#                         "osm_id": 5902886018,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 4538,
#                 "district": "Eastern Suburbs",
#                 "formatted": "Dogue, Oxford Street, Bondi Junction NSW 2022, Australia",
#                 "lat": -33.8905695,
#                 "lon": 151.2436647,
#                 "name": "Dogue",
#                 "place_id": "5112b6e919cce762405945f36d2efef140c0f00103f90182e4d65f01000000920305446f677565",
#                 "postcode": "2022",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Oxford Street",
#                 "suburb": "Bondi Junction"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.18885899999998,
#                     -33.81689019965764
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Petstock",
#                 "address_line2": "1 Frederick Street, Artarmon NSW 2065, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Willoughby City Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "brand": "Petstock",
#                         "brand:wikidata": "Q106540728",
#                         "level:ref": "LG",
#                         "name": "Petstock",
#                         "osm_id": 10786067064,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 5099,
#                 "district": "Lower North Shore",
#                 "formatted": "Petstock, 1 Frederick Street, Artarmon NSW 2065, Australia",
#                 "housenumber": "1",
#                 "lat": -33.8168902,
#                 "lon": 151.188859,
#                 "name": "Petstock",
#                 "place_id": "51c49107220be6624059ebf9a9db8fe840c0f00103f9017852e6820200000092030850657473746f636b",
#                 "postcode": "2065",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Frederick Street",
#                 "suburb": "Artarmon"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2491021,
#                     -33.89352949967118
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Aquapets Aquariums",
#                 "address_line2": "Ebley Street, Bondi Junction NSW 2022, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Waverley Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "name": "Aquapets Aquariums",
#                         "osm_id": 5338208460,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 5102,
#                 "district": "Eastern Suburbs",
#                 "formatted": "Aquapets Aquariums, Ebley Street, Bondi Junction NSW 2022, Australia",
#                 "lat": -33.8935295,
#                 "lon": 151.2491021,
#                 "name": "Aquapets Aquariums",
#                 "place_id": "51ad9bf7a4f8e7624059ab8cb52c5ff240c0f00103f901cc982e3e01000000920312417175617065747320417175617269756d73",
#                 "postcode": "2022",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Ebley Street",
#                 "suburb": "Bondi Junction"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2498808,
#                     -33.89463549967139
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Petbarn",
#                 "address_line2": "Bronte Road, Bondi Junction NSW 2022, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Waverley Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "name": "Petbarn",
#                         "osm_id": 5903363364,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 5243,
#                 "district": "Eastern Suburbs",
#                 "formatted": "Petbarn, Bronte Road, Bondi Junction NSW 2022, Australia",
#                 "lat": -33.8946355,
#                 "lon": 151.2498808,
#                 "name": "Petbarn",
#                 "place_id": "51bffc0406ffe7624059f176826a83f240c0f00103f901242dde5f010000009203075065746261726e",
#                 "postcode": "2022",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Bronte Road",
#                 "suburb": "Bondi Junction"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.1935197644644,
#                     -33.9039294014677
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Petbarn",
#                 "address_line2": "Harley Street Cycleway, Macdonaldtown NSW 2015, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "brand": "Petbarn",
#                         "brand:wikidata": "Q104746468",
#                         "building": "commercial",
#                         "name": "Petbarn",
#                         "osm_id": 61972938,
#                         "osm_type": "w",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 5530,
#                 "formatted": "Petbarn, Harley Street Cycleway, Macdonaldtown NSW 2015, Australia",
#                 "lat": -33.903913,
#                 "lon": 151.19352901096946,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Petbarn",
#                 "place_id": "5123705c5031e66240592b9968f5b3f340c0f00102f901caa1b103000000009203075065746261726e",
#                 "postcode": "2015",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Harley Street Cycleway",
#                 "suburb": "Macdonaldtown"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2533907,
#                     -33.900509499672424
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Puppy Parlour",
#                 "address_line2": "Carrington Road, Queens Park NSW 2024, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Waverley Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "name": "Puppy Parlour",
#                         "osm_id": 6004908494,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 5959,
#                 "district": "Eastern Suburbs",
#                 "formatted": "Puppy Parlour, Carrington Road, Queens Park NSW 2024, Australia",
#                 "lat": -33.9005095,
#                 "lon": 151.2533907,
#                 "name": "Puppy Parlour",
#                 "neighbourhood": "Charing Cross",
#                 "place_id": "518a33d0c61be86240594a6a31e543f340c0f00103f901cea1eb650100000092030d5075707079205061726c6f7572",
#                 "postcode": "2024",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Carrington Road",
#                 "suburb": "Queens Park"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.18121579999996,
#                     -33.906589399673514
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Pets Palace",
#                 "address_line2": "714 King Street, Newtown NSW 2042, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "name": "Pets Palace",
#                         "osm_id": 3275282201,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 6303,
#                 "district": "Inner West",
#                 "formatted": "Pets Palace, 714 King Street, Newtown NSW 2042, Australia",
#                 "housenumber": "714",
#                 "lat": -33.9065894,
#                 "lon": 151.1812158,
#                 "municipality": "Inner West Council",
#                 "name": "Pets Palace",
#                 "place_id": "5196d01385cce5624059bf3f171f0bf440c0f00103f90119d738c30000000092030b506574732050616c616365",
#                 "postcode": "2042",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "King Street",
#                 "suburb": "Newtown"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.16732939999997,
#                     -33.81478269965726
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "PetO",
#                 "address_line2": "Burns Bay Road, Lane Cove NSW 2066, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Lane Cove Municipal Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "name": "PetO",
#                         "osm_id": 10591120332,
#                         "osm_type": "n",
#                         "shop": "pet",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.facilities"
#                 ],
#                 "distance": 6466,
#                 "district": "Lower North Shore",
#                 "formatted": "PetO, Burns Bay Road, Lane Cove NSW 2066, Australia",
#                 "lat": -33.8147827,
#                 "lon": 151.1673294,
#                 "name": "PetO",
#                 "place_id": "5118952fc35ae5624059f02faccc4ae840c0f00103f901ccab4777020000009203045065744f",
#                 "postcode": "2066",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Burns Bay Road",
#                 "suburb": "Lane Cove"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.18410249999997,
#                     -33.797336799654225
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Pet Town",
#                 "address_line2": "Anderson Street, Chatswood NSW 2067, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Chatswood",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "level": 2,
#                         "level:ref": 4,
#                         "name": "Pet Town",
#                         "osm_id": 8401323691,
#                         "osm_type": "n",
#                         "shop": "pet",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.commercial",
#                     "details.facilities"
#                 ],
#                 "distance": 7244,
#                 "district": "Lower North Shore",
#                 "formatted": "Pet Town, Anderson Street, Chatswood NSW 2067, Australia",
#                 "lat": -33.7973368,
#                 "lon": 151.1841025,
#                 "municipality": "Willoughby City Council",
#                 "name": "Pet Town",
#                 "place_id": "519313ed2ae4e5624059c334db210fe640c0f00103f901ab06c2f40100000092030850657420546f776e",
#                 "postcode": "2067",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Anderson Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.19635669999997,
#                     -33.92120979967613
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Petsville / Birdsville",
#                 "address_line2": "684 Botany Road, Alexandria NSW 2015, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Sydney",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 684,
#                         "addr:postcode": 2015,
#                         "addr:state": "NSW",
#                         "addr:street": "Botany Road",
#                         "addr:suburb": "Alexandria",
#                         "name": "Petsville / Birdsville",
#                         "osm_id": 8784419349,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 7299,
#                 "formatted": "Petsville / Birdsville, 684 Botany Road, Alexandria NSW 2015, Australia",
#                 "housenumber": "684",
#                 "lat": -33.9212098,
#                 "lon": 151.1963567,
#                 "municipality": "Council of the City of Sydney",
#                 "name": "Petsville / Birdsville",
#                 "place_id": "51369bd88d48e66240598d2ee533eaf540c0f00103f901159a970b020000009203165065747376696c6c65202f20426972647376696c6c65",
#                 "postcode": "2015",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Botany Road",
#                 "suburb": "Alexandria"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.19381702601592,
#                     -33.79266949266904
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Pet O",
#                 "address_line2": "Victoria Avenue, Chatswood NSW 2067, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Chatswood",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "building": "retail",
#                         "building:levels": 1,
#                         "name": "Pet O",
#                         "osm_id": 553375029,
#                         "osm_type": "w",
#                         "shop": "pet",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details.building",
#                     "details.facilities"
#                 ],
#                 "distance": 7414,
#                 "district": "Lower North Shore",
#                 "formatted": "Pet O, Victoria Avenue, Chatswood NSW 2067, Australia",
#                 "lat": -33.79269585,
#                 "lon": 151.1938364497479,
#                 "municipality": "Willoughby City Council",
#                 "name": "Pet O",
#                 "place_id": "51af84c3bf33e662405975c6a53176e540c0f00102f90135d5fb2000000000920305506574204f",
#                 "postcode": "2067",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Victoria Avenue"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.1855631,
#                     -33.920131699675935
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Peppy Puppy",
#                 "address_line2": "Gardeners Road, Mascot NSW 2020, Australia",
#                 "categories": [
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "country": "Australia",
#                 "country_code": "au",
#                 "county": "Bayside Council",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "name": "Peppy Puppy",
#                         "osm_id": 7615756230,
#                         "osm_type": "n",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 7487,
#                 "formatted": "Peppy Puppy, Gardeners Road, Mascot NSW 2020, Australia",
#                 "lat": -33.9201317,
#                 "lon": 151.1855631,
#                 "name": "Peppy Puppy",
#                 "place_id": "5105bb0622f0e56240597e0f23e0c6f540c0f00103f901c637efc50100000092030b5065707079205075707079",
#                 "postcode": "2020",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Gardeners Road",
#                 "suburb": "Mascot"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.23313721008188,
#                     -33.927640538012696
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Slippery little suckers",
#                 "address_line2": "Anzac Parade, Kingsford NSW 2032, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Randwick City Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "building": "commercial",
#                         "name": "Slippery little suckers",
#                         "osm_id": 279032942,
#                         "osm_type": "w",
#                         "shop": "pet",
#                         "website": "http://www.slipperylittlesuckers.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 7972,
#                 "district": "Eastern Suburbs",
#                 "formatted": "Slippery little suckers, Anzac Parade, Kingsford NSW 2032, Australia",
#                 "lat": -33.92763855,
#                 "lon": 151.23313515532624,
#                 "name": "Slippery little suckers",
#                 "place_id": "5109992adc75e7624059ac9ad6ecbcf640c0f00102f9016eb4a11000000000920317536c697070657279206c6974746c65207375636b657273",
#                 "postcode": "2032",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Anzac Parade",
#                 "suburb": "Kingsford"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.2326974234306,
#                     -33.92826842062496
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Petstock",
#                 "address_line2": "473-477 Anzac Parade, Kingsford NSW 2032, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "building.office",
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Randwick City Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Kingsford",
#                         "addr:housenumber": "473-477",
#                         "addr:postcode": 2032,
#                         "addr:street": "Anzac Parade",
#                         "brand": "Petstock",
#                         "brand:wikidata": "Q106540728",
#                         "building": "commercial",
#                         "building:levels": 2,
#                         "name": "Petstock",
#                         "osm_id": 277751753,
#                         "osm_type": "w",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building"
#                 ],
#                 "distance": 8022,
#                 "district": "Eastern Suburbs",
#                 "formatted": "Petstock, 473-477 Anzac Parade, Kingsford NSW 2032, Australia",
#                 "housenumber": "473-477",
#                 "lat": -33.9282842,
#                 "lon": 151.23269592988305,
#                 "name": "Petstock",
#                 "place_id": "51efefdd4172e7624059343fe67fd1f640c0f00102f901c9278e100000000092030850657473746f636b",
#                 "postcode": "2032",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Anzac Parade",
#                 "suburb": "Kingsford"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     151.12244078000757,
#                     -33.87169827860639
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Fine Pebble Aquarium",
#                 "address_line2": "Parramatta Road, Croydon NSW 2132, Australia",
#                 "categories": [
#                     "building",
#                     "building.commercial",
#                     "commercial",
#                     "commercial.pet",
#                     "pet",
#                     "pet.shop"
#                 ],
#                 "city": "Inner West Council",
#                 "country": "Australia",
#                 "country_code": "au",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "building": "yes",
#                         "name": "Fine Pebble Aquarium",
#                         "osm_id": 1185947109,
#                         "osm_type": "w",
#                         "pet": "fish",
#                         "shop": "pet"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 8712,
#                 "district": "Inner West",
#                 "formatted": "Fine Pebble Aquarium, Parramatta Road, Croydon NSW 2132, Australia",
#                 "lat": -33.8716983,
#                 "lon": 151.12244077641955,
#                 "name": "Fine Pebble Aquarium",
#                 "place_id": "51893aed08ebe3624059064c27cf93ef40c0f00102f901e51db0460000000092031446696e6520506562626c6520417175617269756d",
#                 "postcode": "2132",
#                 "state": "New South Wales",
#                 "state_code": "NSW",
#                 "street": "Parramatta Road",
#                 "suburb": "Croydon"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
# Print the results
print(response["features"][0]["properties"]["name"])
print(response["features"][0]["properties"]["address_line2"])
# Out:
# Pets Point
# Elizabeth Bay Road, Elizabeth Bay NSW 2011, Australia

# %% [markdown]
# ## 5. Find the nearest dentist to your house.
#
# > **Hint:** Use Geoapify Geocode to find your latitude and Geoapify Places to find the dentist.

# %%
# Geoapify Geocode to find latitude and longitude
my_address = "1309 Hay St, West Perth WA 6005, Australia"

# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
# Run request
response = requests.get(base_url, params=params).json()

# Print the json (pretty printed)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "error": "Bad Request",
#     "message": "\"value\" must contain at least one of [text, name, housenumber, postcode, city, state, country]",
#     "statusCode": 400
# }

# %%
# Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]

# Print results
print(f"{my_address}: {lat}, {lon}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Extract lat/lon
# ----> 2 lat = response["features"][0]["properties"]["lat"]
#       3 lon = response["features"][0]["properties"]["lon"]
#       5 # Print results
#
# KeyError: 'features'

# %%
# Set the geographical coordinates for my home


# Set the parameters for the type of place


# Set the parameters for the type of search


# set up a parameters dictionary


# Set base URL

# %%
# Run request


# Print the json (pretty printed)

# %%
# Print the results

# %% [markdown]
# ## 6. Bonus: Find the names and addresses of the five nearest restaurants with internet access in your home city area.
#
# > **Hint:** Read about the `proximity` bias to order the results from the nearest to the farest place. Also, read about the `conditions` to identify places that provide internet access.

# %%
# Set the geographical coordinates for my home


# Set the parameters for the type of place


# Set the parameters for the type of search


# set up a parameters dictionary


# Set base URL

# %%
# Run request


# Print the json (pretty printed)

# %%
# Print the results
